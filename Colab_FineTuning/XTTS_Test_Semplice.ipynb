# %% [markdown]
# # 🎤 Test XTTS v2 su Google Colab
#
# Notebook semplificato per testare voice cloning XTTS v2.

# %%
# Verifica GPU
# !nvidia-smi

# %%
# Installazione TTS
print("📦 Installazione TTS...")
# !pip install -q TTS==0.22.0
# !pip install -q soundfile
print("✅ Installazione completata!")

# %%
# Import librerie
import torch
from TTS.api import TTS
import soundfile as sf

print("🎮 GPU Check:")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
    print(f"VRAM: {torch.cuda.get_device_properties(0).total_memory / 1e9:.2f} GB")

# %%
# Carica modello XTTS v2
print("🔄 Caricamento XTTS v2...")
device = "cuda" if torch.cuda.is_available() else "cpu"
tts = TTS("tts_models/multilingual/multi-dataset/xtts_v2").to(device)
print("✅ XTTS v2 pronto!")

# %%
# Test sintesi italiana
print("🧪 Test sintesi italiana...")

test_text = "Ciao! Questo è un test di sintesi vocale italiana su Google Colab."

tts.tts_to_file(
    text=test_text,
    file_path="/content/test_output.wav",
    language="it"
)

print("✅ Test completato!")
print("📁 File: /content/test_output.wav")

# %%
# Download risultato
from google.colab import files
files.download("/content/test_output.wav")
print("✅ Download completato!")
